# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#Scatter of price per square meter BELGIUM - WITH OUTLIERS
properties_with_outliers = pd.read_csv('cleaned_data_with_outliers.csv')
price_counts = (
    properties_with_outliers
    .groupby('price_square_meter')           # group rows by each unique price
    .size()                     # count how many rows per price
    .reset_index(name='count')  # turn it into a DataFrame with columns ['price','count']
)

# 3) Plot scatter of price vs. count
plt.figure(figsize=(8,5))
sns.scatterplot(data=price_counts, x='price_square_meter', y='count')
plt.xlabel("Price square meter (€ per sqm)")
plt.ylabel("Number of Properties")
plt.title("Price Per Square Meter vs Frequency")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Scatter of price per square meter - BRUSSELS - WITH OUTLIERS X

properties_with_outliers = pd.read_csv('cleaned_data_with_outliers.csv')
region_df = properties_with_outliers[properties_with_outliers["region"] == "Brussels"]
price_counts = (
    region_df
    .groupby('price_square_meter')
    .size()
    .reset_index(name='count')
)

# 3) Plot scatter of price vs. count
plt.figure(figsize=(8,5))
sns.scatterplot(data=price_counts, x='price_square_meter', y='count')
plt.xlabel("Price square meter (€ per sqm)")
plt.ylabel("Number of Properties")
plt.title("Price Per Square Meter vs Frequency- Brussels")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


# Scatter of price per square meter - Flanders - WITH OUTLIERS
properties_with_outliers = pd.read_csv('cleaned_data_with_outliers.csv')
region_df = properties_with_outliers[properties_with_outliers["region"] == "Flanders"]
price_counts = (
    region_df
    .groupby('price_square_meter')
    .size()
    .reset_index(name='count')
)

# 3) Plot scatter of price vs. count
plt.figure(figsize=(8,5))
sns.scatterplot(data=price_counts, x='price_square_meter', y='count')
plt.xlabel("Price square meter (€ per sqm)")
plt.ylabel("Number of Properties")
plt.title("Price Per Square Meter vs Frequency- Flanders")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


# Scatter of price per square meter - Wallonia - WITH OUTLIERS
properties_with_outliers = pd.read_csv('cleaned_data_with_outliers.csv')
region_df = properties_with_outliers[properties_with_outliers["region"] == "Wallonia"]
price_counts = (
    region_df
    .groupby('price_square_meter')
    .size()
    .reset_index(name='count')
)

# 3) Plot scatter of price vs. count
plt.figure(figsize=(8,5))
sns.scatterplot(data=price_counts, x='price_square_meter', y='count')
plt.xlabel("Price square meter (€ per sqm)")
plt.ylabel("Number of Properties")
plt.title("Price Per Square Meter vs Frequency- Wallonia")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Scatter of price per square meter BELGIUM - NO OUTLIERS
properties = pd.read_csv('cleaned_data.csv')
price_counts = (
    properties
    .groupby('price_square_meter')           # group rows by each unique price
    .size()                     # count how many rows per price
    .reset_index(name='count')  # turn it into a DataFrame with columns ['price','count']
)

# 3) Plot scatter of price vs. count
plt.figure(figsize=(8,5))
sns.scatterplot(data=price_counts, x='price_square_meter', y='count')
plt.xlabel("Price square meter (€ per sqm)")
plt.ylabel("Number of Properties")
plt.title("Price Per Square Meter vs Frequency")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Scatter of price per square meter - BRUSSELS - WITH NO OUTLIERS

properties = pd.read_csv('cleaned_data.csv')
region_df = properties[properties["region"] == "Brussels"]
price_counts = (
    region_df
    .groupby('price_square_meter')
    .size()
    .reset_index(name='count')
)

# 3) Plot scatter of price vs. count
plt.figure(figsize=(8,5))
sns.scatterplot(data=price_counts, x='price_square_meter', y='count')
plt.xlabel("Price square meter (€ per sqm)")
plt.ylabel("Number of Properties")
plt.title("Price Per Square Meter vs Frequency- Brussels")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


# Scatter of price per square meter - Flanders - WITH NO OUTLIERS
properties = pd.read_csv('cleaned_data.csv')
region_df = properties[properties["region"] == "Flanders"]
price_counts = (
    region_df
    .groupby('price_square_meter')
    .size()
    .reset_index(name='count')
)

# 3) Plot scatter of price vs. count
plt.figure(figsize=(8,5))
sns.scatterplot(data=price_counts, x='price_square_meter', y='count')
plt.xlabel("Price square meter (€ per sqm)")
plt.ylabel("Number of Properties")
plt.title("Price Per Square Meter vs Frequency- Flanders")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


# Scatter of price per square meter - Wallonia - WITH NO OUTLIERS
properties = pd.read_csv('cleaned_data.csv')
region_df = properties[properties["region"] == "Wallonia"]
price_counts = (
    region_df
    .groupby('price_square_meter')
    .size()
    .reset_index(name='count')
)

# 3) Plot scatter of price vs. count
plt.figure(figsize=(8,5))
sns.scatterplot(data=price_counts, x='price_square_meter', y='count')
plt.xlabel("Price square meter (€ per sqm)")
plt.ylabel("Number of Properties")
plt.title("Price Per Square Meter vs Frequency- Wallonia")
plt.tight_layout()
plt.show()

# %%
# Average property price by province

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
avg_price = properties.groupby('province')['price'].mean().sort_values()
avg_price.plot(kind='barh')
plt.title('Average Property Price by Province')
plt.show()

# %%
# Average property price per square meter by province
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
avg_price = properties.groupby('province')['price_square_meter'].mean().sort_values()
avg_price.plot(kind='barh')
plt.title('Average Property Price Per Square Meter by Province')
plt.show()

# %%
# Top property price per square meter by postcode - Belgium
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
avg_price = (
    properties.groupby('MunicipalityCleanName')['price_square_meter']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)
avg_price = avg_price.iloc[::-1]
avg_price.plot(kind='barh', color='midnightblue')
plt.xlabel('Price per sqm (€)')
plt.ylabel('Municipality')
plt.title('10 Most Expensive Municipalities in Belgium (€/sqm)')
plt.tight_layout()
plt.show()

# %%
# Top property avg price by postcode - Belgium
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
avg_price = (
    properties.groupby('MunicipalityCleanName')['price']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)
avg_price = avg_price.iloc[::-1]
avg_price.plot(kind='barh', color='cornflowerblue')
plt.xlabel('Average Price (€)')
plt.ylabel('Municipality')
plt.title('10 Most Expensive Municipalities in Belgium (€)')
plt.tight_layout()
plt.show()

# %%
# Top property avg price by postcode - Belgium
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
avg_price = (
    properties.groupby('MunicipalityCleanName')['price']
    .median()
    .sort_values(ascending=False)
    .head(10)
)
avg_price = avg_price.iloc[::-1]
avg_price.plot(kind='barh', color='skyblue')
plt.xlabel('Median Price (€)')
plt.ylabel('Municipality')
plt.title('10 Most Expensive Municipalities in Belgium(€)')
plt.tight_layout()
plt.show()

# %%
# Bottom property price per square meter by postcode - Belgium
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
avg_price = (
    properties.groupby('MunicipalityCleanName')['price_square_meter']
    .mean()
    .sort_values(ascending=False)
    .tail(10)
)

avg_price.plot(kind='barh', color='midnightblue')
plt.xlabel('Price per sqm (€)')
plt.ylabel('Municipality')
plt.title('10 Least Expensive Municipalities in Belgium (€/sqm)')
plt.tight_layout()
plt.show()

# %%
# Bottom property average price by postcode - Belgium
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
avg_price = (
    properties.groupby('MunicipalityCleanName')['price']
    .mean()
    .sort_values(ascending=False)
    .tail(10)
)

avg_price.plot(kind='barh', color='cornflowerblue')
plt.xlabel('Average Price (€)')
plt.ylabel('Municipality')
plt.title('10 Least Expensive Municipalities in Belgium (€)')
plt.tight_layout()
plt.show()

# %%
# Bottom property average price by postcode - Belgium
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
avg_price = (
    properties.groupby('MunicipalityCleanName')['price']
    .median()
    .sort_values(ascending=False)
    .tail(10)
)

avg_price.plot(kind='barh', color='skyblue')
plt.xlabel('Median Price (€)')
plt.ylabel('Municipality')
plt.title('10 Least Expensive Municipalities in Belgium (€)')
plt.tight_layout()
plt.show()

# %%
# Top property price per square meter by postcode - Wallonia
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
properties_wallonia = properties.loc[properties["region"] == "Wallonia"]
avg_price = (
    properties_wallonia.groupby('MunicipalityCleanName')['price_square_meter']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)
avg_price = avg_price.iloc[::-1]
avg_price.plot(kind='barh', color='darkgreen')
plt.xlabel('Price per sqm (€)')
plt.ylabel('Municipality')
plt.title('10 Most Expensive Municipalities in Wallonia (€/sqm)')
plt.tight_layout()
plt.show()

# %%
# Top property avg price by postcode - Wallonia
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
properties_wallonia = properties.loc[properties["region"] == "Wallonia"]
avg_price = (
    properties_wallonia.groupby('MunicipalityCleanName')['price']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)
avg_price = avg_price.iloc[::-1]
avg_price.plot(kind='barh', color='mediumseagreen')
plt.xlabel('Average Price (€)')
plt.ylabel('Municipality')
plt.title('10 Most Expensive Municipalities in Wallonia (€)')
plt.tight_layout()
plt.show()

# %%
# Top property avg price by postcode - Wallonia
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
properties_wallonia = properties.loc[properties["region"] == "Wallonia"]
avg_price = (
    properties_wallonia.groupby('MunicipalityCleanName')['price']
    .median()
    .sort_values(ascending=False)
    .head(10)
)
avg_price = avg_price.iloc[::-1]
avg_price.plot(kind='barh', color='palegreen')
plt.xlabel('Median Price (€)')
plt.ylabel('Municipality')
plt.title('10 Most Expensive Municipalities in Wallonia(€)')
plt.tight_layout()
plt.show()

# %%
# Bottom property price per square meter by postcode - Wallonia
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
properties_wallonia = properties.loc[properties["region"] == "Wallonia"]
avg_price = (
    properties_wallonia.groupby('MunicipalityCleanName')['price_square_meter']
    .mean()
    .sort_values(ascending=False)
    .tail(10)
)

avg_price.plot(kind='barh', color='darkgreen')
plt.xlabel('Price per sqm (€)')
plt.ylabel('Municipality')
plt.title('10 Least Expensive Municipalities in Wallonia (€/sqm)')
plt.tight_layout()
plt.show()

# %%
# Bottom property average price by postcode - Wallonia
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
properties_wallonia = properties.loc[properties["region"] == "Wallonia"]
avg_price = (
    properties_wallonia.groupby('MunicipalityCleanName')['price']
    .mean()
    .sort_values(ascending=False)
    .tail(10)
)

avg_price.plot(kind='barh', color='mediumseagreen')
plt.xlabel('Average Price (€)')
plt.ylabel('Municipality')
plt.title('10 Least Expensive Municipalities in Wallonia (€)')
plt.tight_layout()
plt.show()

# %%
# Bottom property average price by postcode - Wallonia
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
properties_wallonia = properties.loc[properties["region"] == "Wallonia"]
avg_price = (
    properties_wallonia.groupby('MunicipalityCleanName')['price']
    .median()
    .sort_values(ascending=False)
    .tail(10)
)

avg_price.plot(kind='barh', color='palegreen')
plt.xlabel('Median Price (€)')
plt.ylabel('Municipality')
plt.title('10 Least Expensive Municipalities in Wallonia (€)')
plt.tight_layout()
plt.show()

# %%
# Top property price per square meter by postcode - Flanders
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
properties_flanders = properties.loc[properties["region"] == "Flanders"]
avg_price = (
    properties_flanders.groupby('MunicipalityCleanName')['price_square_meter']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)
avg_price = avg_price.iloc[::-1]
avg_price.plot(kind='barh', color='saddlebrown')
plt.xlabel('Price per sqm (€)')
plt.ylabel('Municipality')
plt.title('10 Most Expensive Municipalities in Flanders (€/sqm)')
plt.tight_layout()
plt.show()

# %%
# Top property avg price by postcode - Flanders
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
properties_flanders = properties.loc[properties["region"] == "Flanders"]
avg_price = (
    properties_flanders.groupby('MunicipalityCleanName')['price']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)
avg_price = avg_price.iloc[::-1]
avg_price.plot(kind='barh', color='peru')
plt.xlabel('Average Price (€)')
plt.ylabel('Municipality')
plt.title('10 Most Expensive Municipalities in Flanders (€)')
plt.tight_layout()
plt.show()

# %%
# Top property avg price by postcode - Flanders
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
properties_flanders = properties.loc[properties["region"] == "Flanders"]
avg_price = (
    properties_flanders.groupby('MunicipalityCleanName')['price']
    .median()
    .sort_values(ascending=False)
    .head(10)
)
avg_price = avg_price.iloc[::-1]
avg_price.plot(kind='barh', color='bisque')
plt.xlabel('Median Price (€)')
plt.ylabel('Municipality')
plt.title('10 Most Expensive Municipalities in Flanders(€)')
plt.tight_layout()
plt.show()

# %%
# Bottom property price per square meter by postcode - Flanders
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
properties_flanders = properties.loc[properties["region"] == "Flanders"]
avg_price = (
    properties_flanders.groupby('MunicipalityCleanName')['price_square_meter']
    .mean()
    .sort_values(ascending=False)
    .tail(10)
)

avg_price.plot(kind='barh', color='saddlebrown')
plt.xlabel('Price per sqm (€)')
plt.ylabel('Municipality')
plt.title('10 Least Expensive Municipalities in Flanders (€/sqm)')
plt.tight_layout()
plt.show()

# %%
# Bottom property average price by postcode - Flanders
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
properties_flanders = properties.loc[properties["region"] == "Flanders"]
avg_price = (
    properties_flanders.groupby('MunicipalityCleanName')['price']
    .mean()
    .sort_values(ascending=False)
    .tail(10)
)

avg_price.plot(kind='barh', color='peru')
plt.xlabel('Average Price (€)')
plt.ylabel('Municipality')
plt.title('10 Least Expensive Municipalities in Flanders (€)')
plt.tight_layout()
plt.show()

# %%
# Bottom property average price by postcode - Flanders
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd    

properties = pd.read_csv('cleaned_data.csv')
properties_flanders = properties.loc[properties["region"] == "Flanders"]
avg_price = (
    properties_flanders.groupby('MunicipalityCleanName')['price']
    .median()
    .sort_values(ascending=False)
    .tail(10)
)

avg_price.plot(kind='barh', color='bisque')
plt.xlabel('Median Price (€)')
plt.ylabel('Municipality')
plt.title('10 Least Expensive Municipalities in Flanders (€)')
plt.tight_layout()
plt.show()
